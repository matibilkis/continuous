# %% [markdown]
# This is a noisy trajectory, without weigths

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:90% !important;</style>"))
import os 
os.chdir("..")
# %load_ext autoreload
# %autoreload 2
from tqdm import tqdm
from numerics.integration.matrices import *
from numerics.utilities.misc import *
import matplotlib.pyplot as plt
# Out:
# <style>.container {width:90% !important;</style>

# %%
from numerics.machine_learning.misc import *

# %%
# %load_ext autoreload
# %autoreload 2params, exp_path = def_params()
xi, kappa, omega, eta = params

T = 100.
dt = 1e-3

itraj=1
train_id = 0
total_time,dt = T*kappa, kappa*dt


states_si, dys_si = load(itraj=1, exp_path=exp_path, total_time=total_time, dt=dt, ext_signal=1)
save_dir = get_training_save_dir(exp_path, total_time, dt, itraj,train_id)
loss = np.load(save_dir+"loss.npy")
grads = np.load(save_dir+"grads.npy")
params = np.load(save_dir+"params.npy")
plot_history(data=[loss,params,grads])

# %%
loss = np.load(save_dir+"loss.npy")
grads = np.load(save_dir+"grads.npy")
params = np.load(save_dir+"params.npy")

# %%
loss = np.load(save_dir+"loss.npy")
grads = np.load(save_dir+"grads.npy")
params = np.load(save_dir+"params.npy")
plot_history(data=[loss,params,grads])

# %%
plt.plot(dys_si[:,0])

# %%
plt.plot(states_si[:,0])

# %%
params, exp_path = def_params()



initial_parameters = np.array([10., 4*2*np.pi/total_time]).astype(np.float32)
true_parameters = np.array([10., 4*2*np.pi/total_time]).astype(np.float32)

# %%
[xi, kappa, omega, eta] = 0, 1, 0, 10
params = [xi, kappa, omega, eta]

A, D , E, B  = genoni_matrices(*params)
xicov, covss = genoni_xi_cov(A,D, E, B ,params, stat=True)

# %%
B
# Out:
# array([[-3.16227766, -0.        ],
#        [-0.        , -0.        ]])

# %%
params, exp_path = def_params()

initial_parameters = np.array([10., 4*2*np.pi/total_time]).astype(np.float32)
true_parameters = np.array([10., 4*2*np.pi/total_time]).astype(np.float32)


A, D , E, B  = genoni_matrices(*params)
xicov, covss = genoni_xi_cov(A,D, E, B ,params, stat=True)

BS = 1#len(tfsignals[0])
batch_shape = [BS, None, 3]
model = Model(params=params, dt=dt, initial_parameters=initial_parameters,
              true_parameters=true_parameters, initial_states = np.zeros((1,5)).astype(np.float32),
              cov_in=covss, batch_size=tuple([None,None,3]))#tuple(batch_shape))
model.recurrent_layer.build(tf.TensorShape(batch_shape))
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-2))

# %%
preds = model.predict(tfsignals)
# Out:
# 2022-05-17 17:08:24.710912: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %%
plt.plot(np.squeeze(tfsignals[:,:,1]))
plt.plot(preds[0,:,0])

# %%
np.unique(amps)
# Out:
# array([  1.        ,   1.66810054,   2.7825594 ,   4.64158883,
#          7.74263683,  10.        ,  12.91549665,  21.5443469 ,
#         35.93813664,  59.94842503, 100.        ])

# %%
def logito(A, N=9):
    aa = np.unique(np.sort(list(np.logspace(np.log10(A/100), np.log10(10*A), N)) + [A]))
    return aa

amps = logito(true_parameters[0])
freqs = logito(true_parameters[1])

loss ={}
true_omega = true_parameters[1]
A = true_parameters[0]
for amplitude in tqdm(amps):

    for omega in freqs:
        model.trainable_variables[0].assign(tf.convert_to_tensor(np.array([[ amplitude, omega ]]).astype(np.float32)))
        preds = model.predict(tfsignals)
        loss[str([amplitude, omega])] = tf.keras.losses.mse(np.squeeze(tfsignals[:,:,1]), preds[0,:,0])
# Out:
#  70%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                | 7/10 [02:02<00:52, 17.62s/it]

# %%
X,Y = np.meshgrid(amps, freqs)

# %%
valls = np.squeeze(list(loss.values()))

# %%
plt.imshow(np.reshape(valls, (9,10)))

# %%
plt.imshow(np.reshape(np.squeeze(list(loss.values())), (9,10)))

# %%
plt.imshow(amps, freqs, np.reshape(np.squeeze(list(loss.values())), (9,10)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
# ----> 1 plt.imshow(amps, freqs, np.reshape(np.squeeze(list(loss.values())), (9,10)))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:459, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     453 if len(args) > name_idx:
#     454     warn_deprecated(
#     455         since, message="Passing the %(name)s %(obj_type)s "
#     456         "positionally is deprecated since Matplotlib %(since)s; the "
#     457         "parameter will become keyword-only %(removal)s.",
#     458         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2652, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2646 @_copy_docstring_and_deprecators(Axes.imshow)
#    2647 def imshow(
#    2648         X, cmap=None, norm=None, aspect=None, interpolation=None,
#    2649         alpha=None, vmin=None, vmax=None, origin=None, extent=None, *,
#    2650         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2651         resample=None, url=None, data=None, **kwargs):
# -> 2652     __ret = gca().imshow(
#    2653         X, cmap=cmap, norm=norm, aspect=aspect,
#    2654         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2655         vmax=vmax, origin=origin, extent=extent,
#    2656         interpolation_stage=interpolation_stage,
#    2657         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2658         url=url, **({"data": data} if data is not None else {}),
#    2659         **kwargs)
#    2660     sci(__ret)
#    2661     return __ret
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:459, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     453 if len(args) > name_idx:
#     454     warn_deprecated(
#     455         since, message="Passing the %(name)s %(obj_type)s "
#     456         "positionally is deprecated since Matplotlib %(since)s; the "
#     457         "parameter will become keyword-only %(removal)s.",
#     458         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5475, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5473     aspect = rcParams['image.aspect']
#    5474 self.set_aspect(aspect)
# -> 5475 im = mimage.AxesImage(self, cmap, norm, interpolation,
#    5476                       origin, extent, filternorm=filternorm,
#    5477                       filterrad=filterrad, resample=resample,
#    5478                       interpolation_stage=interpolation_stage,
#    5479                       **kwargs)
#    5481 im.set_data(X)
#    5482 im.set_alpha(alpha)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/image.py:929, in AxesImage.__init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     913 def __init__(self, ax,
#     914              cmap=None,
#     915              norm=None,
#    (...)
#     924              **kwargs
#     925              ):
#     927     self._extent = extent
# --> 929     super().__init__(
#     930         ax,
#     931         cmap=cmap,
#     932         norm=norm,
#     933         interpolation=interpolation,
#     934         origin=origin,
#     935         filternorm=filternorm,
#     936         filterrad=filterrad,
#     937         resample=resample,
#     938         interpolation_stage=interpolation_stage,
#     939         **kwargs
#     940     )
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/image.py:246, in _ImageBase.__init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     233 def __init__(self, ax,
#     234              cmap=None,
#     235              norm=None,
#    (...)
#     243              **kwargs
#     244              ):
#     245     martist.Artist.__init__(self)
# --> 246     cm.ScalarMappable.__init__(self, norm, cmap)
#     247     if origin is None:
#     248         origin = mpl.rcParams['image.origin']
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/cm.py:357, in ScalarMappable.__init__(self, norm, cmap)
#     355 self._A = None
#     356 self._norm = None  # So that the setter knows we're initializing.
# --> 357 self.set_norm(norm)  # The Normalize instance of this ScalarMappable.
#     358 self.cmap = None  # So that the setter knows we're initializing.
#     359 self.set_cmap(cmap)  # The Colormap instance of this ScalarMappable.
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/cm.py:589, in ScalarMappable.set_norm(self, norm)
#     575 def set_norm(self, norm):
#     576     """
#     577     Set the normalization instance.
#     578
#    (...)
#     587     on the colorbar to default.
#     588     """
# --> 589     self.norm = norm
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/cm.py:557, in ScalarMappable.norm(self, norm)
#     555 @norm.setter
#     556 def norm(self, norm):
# --> 557     _api.check_isinstance((colors.Normalize, None), norm=norm)
#     558     if norm is None:
#     559         norm = colors.Normalize()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/_api/__init__.py:93, in check_isinstance(_types, **kwargs)
#      91     names.remove("None")
#      92     names.append("None")
# ---> 93 raise TypeError(
#      94     "{!r} must be an instance of {}, not a {}".format(
#      95         k,
#      96         ", ".join(names[:-1]) + " or " + names[-1]
#      97         if len(names) > 1 else names[0],
#      98         type_name(type(v))))
#
# TypeError: 'norm' must be an instance of matplotlib.colors.Normalize or None, not a numpy.ndarray

# %%
plt.imshow(qa
# Out:
# array([3.0754559e-02, 3.0852439e-02, 3.1133285e-02, 3.1360347e-02,
#        2.4591617e-02, 2.4535026e-02, 3.0517811e-02, 3.0469306e-02,
#        3.0498883e-02, 3.0442541e-02, 3.1286538e-02, 3.1759184e-02,
#        3.2221068e-02, 3.2612164e-02, 2.0497290e-02, 2.0412367e-02,
#        3.0927381e-02, 3.0689288e-02, 3.0638654e-02, 3.0496344e-02,
#        3.3314705e-02, 3.4571849e-02, 3.5274513e-02, 3.5929881e-02,
#        1.4139017e-02, 1.4037686e-02, 3.2344032e-02, 3.1440496e-02,
#        3.1023990e-02, 3.0637756e-02, 3.9815865e-02, 4.3368995e-02,
#        4.4243146e-02, 4.5281779e-02, 5.7497001e-03, 5.7266196e-03,
#        3.7039902e-02, 3.3914827e-02, 3.2141808e-02, 3.1033838e-02,
#        6.0530018e-02, 7.1015015e-02, 7.1382485e-02, 7.2828397e-02,
#        5.7015288e-05, 5.1280949e-04, 5.2273706e-02, 4.1915044e-02,
#        3.5497539e-02, 3.2195512e-02, 1.2631074e-01, 1.5813179e-01,
#        1.5503149e-01, 1.5633462e-01, 1.9108560e-02, 2.1490229e-02,
#        1.0113039e-01, 6.7526400e-02, 4.5790751e-02, 3.5707477e-02,
#        3.3481997e-01, 4.3307206e-01, 4.1568848e-01, 4.1399565e-01,
#        1.4524609e-01, 1.5444978e-01, 2.5684360e-01, 1.4907224e-01,
#        7.7774324e-02, 4.6525955e-02, 9.9505955e-01, 1.3015367e+00,
#        1.2330862e+00, 1.2173945e+00, 6.6130060e-01, 6.9337851e-01,
#        7.5141203e-01, 4.0793082e-01, 1.7790791e-01, 8.0226064e-02,
#        3.0844777e+00, 4.0461345e+00, 3.8057055e+00, 3.7377000e+00,
#        2.5015757e+00, 2.6083028e+00, 2.3192167e+00, 1.2282708e+00,
#        4.9276701e-01, 1.8588665e-01], dtype=float32)

# %%
ax=plt.subplot(111)
ax.plot(np.squeeze(list(loss.keys())), np.squeeze(list(loss.values())))
ax.scatter( [true_parameters[1]],[0], color="black",s=300)

# %%
spp = tf.split(tfsignals, 50, axis=1)

# %%
n_epochs = 10

# %%
cc = []
for epoch in range(n_epochs):
    model.reset_states()  
    for k in spp:
        bb = model.train_step((k,k))
        cc+=[bb]
    loss =  np.squeeze(bb["LOSS"].numpy())
    print("\r EPOCH {}/{}   loss:{}    params{}    grads{}".format(epoch, n_epochs,loss, np.squeeze(bb["PARAMS"].numpy()), np.squeeze(bb["GRADS"].numpy())),end="")
    if loss<1e-10:
        break
# Out:
# 2022-05-17 16:10:43.783747: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#  EPOCH 9/10   loss:0.06193508207798004    params[ 9.124218   -0.25412917]    grads[-0.01976766  5.8980484 ]]1]

# %%
def plot_history(cc, preds=None):
    plt.figure(figsize=(20,5))
    if preds is None:

        ax1 = plt.subplot(131)
        ax2 = plt.subplot(132)
        ax3 = plt.subplot(133)       
    else:
        ax1 = plt.subplot(141)
        ax2 = plt.subplot(142)
        ax3 = plt.subplot(143)       
        ax4 = plt.subplot(144)
    
    history_loss = np.squeeze([cc[k]["LOSS"] for k in range(len(cc))])
    ax1.set_title("LOSS")
    ax1.plot(history_loss)
    ax1.loglog()
    ax1.set_xlabel("GRADIENT STEP")
    
    params=np.squeeze([cc[k]["PARAMS"] for k in range(len(cc))])
    ax2.set_title("PARAMS")
    ax2.plot(params[:,0],label="RNN")
    ax2.plot(np.ones(len(params))*true_parameters[0], '--',label="true")
    ax2.set_xlabel("GRADIENT STEP")
    ax2.legend()
    
    grads = np.squeeze([cc[k]["LOSS"] for k in range(len(cc))])
    ax3.set_title("GRADS")
    ax3.plot(grads)
    ax3.loglog()
    
    
    if preds is not None:
        ax4.set_title("PREDICTIONS")
        ax4.plot(np.squeeze(preds)[:,0], '--',color="red", alpha=0.5,label="RNN")
        ax4.plot(dd[0], color="blue", label="true", alpha=0.5)
        ax4.legend()

# %%
freq = 4*2*np.pi/10

# %%
model.trainable_variables[0].assign(tf.convert_to_tensor(np.array([[10. , freq]]).astype(np.float32)))
# Out:
# <tf.Variable 'UnreadVariable' shape=(1, 2) dtype=float32, numpy=array([[10.       ,  2.5132742]], dtype=float32)>

# %%
preds = model.predict(tfsignals)

# %%
model.reset_states()
preds = model.predict(tfsignals)

# %%
plot_history(cc, preds)

# %%
loss = [cc[k]["LOSS"].numpy() for k in range(len(cc))]
grads = np.squeeze([cc[k]["GRADS"].numpy() for k in range(len(cc))])
params = np.squeeze([cc[k]["PARAMS"].numpy() for k in range(len(cc))])
