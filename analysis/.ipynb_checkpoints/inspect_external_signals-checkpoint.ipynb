# %%
# %load_ext autoreload
# %autoreload 2

import os 
os.chdir("..")

from numerics.utilities.misc import * 
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def load(itraj = 1,total_time = 50., dt = 1e-3, exp_path="", ext_signal=1):
    pp = get_path_config(total_time=total_time, dt=dt, itraj=itraj, exp_path = exp_path, ext_signal=ext_signal)
    states = np.load(pp+"states.npy")
    dys = np.load(pp+"dys.npy")
    return states, dys

# %%
params, exp_path = def_params()

# %%
total_time = 100.
dt = 1e-3

# %%
states_no, dys_no = load(itraj=1, exp_path=exp_path, total_time=total_time, dt=dt, ext_signal=0)
states_si, dys_si = load(itraj=1, exp_path=exp_path, total_time=total_time, dt=dt, ext_signal=1)

# %%
plt.figure(figsize=(7,6))
ax00,ax01 = plt.subplot(221),plt.subplot(222)
ax10,ax11 = plt.subplot(221),plt.subplot(222)

ax00.plot(states_no[:,0])
ax01.plot(dys_no[:,0])

ax10.plot(states_si[:,0])
ax11.plot(dys_si[:,0])

# %%
spectra_signal = np.fft.fft(dys_si[:,0])
freqs_signal = np.fft.fftfreq(n = len(spectra_signal), d= dt)*(2*np.pi)

# %%
plt.plot(freqs_signal,spectra_signal)
plt.loglog()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# []

# %%
xi, kappa, omega, eta = params

# %%
def give_matrices(xi, kappa, omega, eta):
    A = np.array([[-(xi + .5*kappa), omega], [-omega, xi - 0.5*kappa]])
    D = kappa*np.eye(2)
    E = B = -np.sqrt(eta*kappa)*np.array([[1.,0.],[0.,0.]])
    return A, D, E, B

# %%
A, D, E, B = give_matrices(xi, kappa, omega, eta)
A
# Out:
# array([[-0.99,  0.  ],
#        [-0.  , -0.01]])
