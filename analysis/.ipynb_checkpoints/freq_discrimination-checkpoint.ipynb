# %%
import os 
os.chdir("..")

# %%
# %load_ext autoreload
# %autoreload 2
from numerics.integration.steps import *
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from numerics.utilities.misc import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
params = give_def_params()
params, exp_path = check_params(params)
[eta, gamma, kappa, omega, n] = params

# %%
def load_liks(itrajj, mode="frequencies"):
    pars = give_def_params_discrimination(flip=0, mode = mode)
    params, exp_path = check_params(pars)

    total_time, dt = get_total_time_dt(params, ppp=1000)
    
    logliks =load_data_discrimination_liks(itraj=itrajj, total_time = total_time, dt=dt, exp_path = exp_path)
    l0,l1 = logliks[:,0], logliks[:,1]
    log_lik_ratio = l1 - l0  ###

    pars = give_def_params_discrimination(flip=1, mode=mode)
    params, exp_path = check_params(pars)
    total_time, dt = get_total_time_dt(params, ppp=1000)
    logliks_swap =load_data_discrimination_liks(itraj=itrajj, total_time = total_time, dt=dt, exp_path = exp_path)
    log_lik_ratio_swap = logliks[:,0] - logliks[:,1]  
    
    return log_lik_ratio, log_lik_ratio_swap

# %%
indis = np.logspace(2,np.log10(len(times)), 10)
indis = [int(k) for k in indis]

# %%
def decide_stop(l, a, b):
    if a<=l<=b:
        return 0
    else:
        return 1

# %%
deter, stoch = {}, {}
deter["h0/h1"]  = []
deter["h1/h0"] = []
stoch["h1/h0"] = {}
stoch["h0/h1"] = {}
stop = {}
stop["h1/h0"] = {i:[] for i in range(1,2)}
stop["h0/h1"] = {i:[] for i in range(1,2)}


boundsB = np.arange(1,2,1)
boundsA = np.sort(-boundsB)[::-1]
for ind_bound in range(len(boundsB)):
    stoch["h0/h1"][ind_bound] = []
    stoch["h1/h0"][ind_bound] = []    

    
itraj = 1
log_lik_ratio, log_lik_ratio_swap = load_liks(itraj)

ll = log_lik_ratio
ll0 = log_lik_ratio_swap
for time_index in tqdm(indis):
    h0_deter = log_lik_ratio[time_index] <= 0
    h1_deter = log_lik_ratio_swap[time_index] <= 0
    deter["h0/h1"].append(int(h0_deter))
    deter["h1/h0"].append(int(h0_deter))
    for ind_bound, a, b in zip(range(len(boundsB)), boundsA, boundsB):
        stoch["h0/h1"][ind_bound].append(decide_stop(log_lik_ratio[time_index], a, b))
        stoch["h1/h0"][ind_bound].append(decide_stop(log_lik_ratio_swap[time_index], a, b))
for b in np.arange(1,20,2):
    stop["h0/h1"][itraj].append(times[np.argmin(np.logical_and(log_lik_ratio < b, log_lik_ratio > -b))])
    stop["h1/h0"][itraj].append(times[np.argmin(np.logical_and(log_lik_ratio_swap < b, log_lik_ratio_swap > -b))])
n=1
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 14995.72it/s]

# %%
for itraj in tqdm(range(2,1000)):
    try:
        log_lik_ratio, log_lik_ratio_swap = load_liks(itraj)
        stop["h0/h1"][itraj] = []
        stop["h1/h0"][itraj] = []
        ll += log_lik_ratio
        ll0+= log_lik_ratio_swap
        n+=1
        for ind, time_index in enumerate(indis):
            h0_deter = log_lik_ratio[time_index] <= 0
            h1_deter = log_lik_ratio_swap[time_index] <= 0
            deter["h0/h1"][ind] +=  (int(h0_deter) - deter["h0/h1"][ind] )/n
            deter["h1/h0"][ind] += (int(h0_deter) - deter["h1/h0"][ind])/n
        for b in np.arange(1,20,2):
            stop["h0/h1"][itraj].append(times[np.argmin(np.logical_and(log_lik_ratio < b, log_lik_ratio > -b))])
            stop["h1/h0"][itraj].append(times[np.argmin(np.logical_and(log_lik_ratio_swap < b, log_lik_ratio_swap > -b))])
    except Exception:
        pass
# Out:
# 100%|██████████| 998/998 [00:02<00:00, 476.94it/s]

# %%
ll = ll/len(stop["h0/h1"])
ll0 = ll0/len(stop["h0/h1"])

# %%
colors1 = plt.get_cmap("Reds")
colors0 = plt.get_cmap("Blues")

# %%
plt.figure(figsize=(10,10))
plt.plot(ll,linewidth=10,  color="red", label=r'$\langle \ell_{|H_1}\rangle$')
Ntraj = 10
c1 = colors1(np.linspace(0,1,Ntraj))[::-1]
c0 = colors0(np.linspace(0,1,Ntraj))[::-1]
             
for ii, itraj in enumerate(range(1,Ntraj)):
    log_lik_ratio, log_lik_ratio_swap = load_liks(itraj)
    plt.plot(log_lik_ratio, c=c1[ii], alpha=0.75)
    plt.plot(log_lik_ratio_swap,c=c0[ii], alpha=0.75)
plt.plot(ll0, linewidth=10, color="blue", label=r'$\langle \ell_{|H_0}\rangle$')
plt.legend(prop={"size":20})

# %%
stoping_times_bounds = [np.mean([stop["h0/h1"][k][bb] for k in list(stop["h0/h1"].keys())]) for bb, bound in enumerate(np.arange(1,19,2))]
stoping_times_bounds_swap = [np.mean([stop["h1/h0"][k][bb] for k in list(stop["h0/h1"].keys())]) for bb, bound in enumerate(np.arange(1,19,2))]

# %%
plt.plot(np.arange(1,19,2),stoping_times_bounds)
plt.plot(np.arange(1,19,2),stoping_times_bounds_swap)

# %%
plt.plot(log_lik_ratio_swap)
plt.plot(-log_lik_ratio)

# %%
pars = give_def_params_discrimination(flip=0, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)

total_time, dt = get_total_time_dt(params, ppp=1e3)
times, logliks, states1, states0, signals, covs1, covs0 =load_data_discrimination(itraj=10, total_time = total_time, dt=dt, exp_path = exp_path)

pars = give_def_params_discrimination(flip=1, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)

total_time, dt = get_total_time_dt(params, ppp=1e3)
times, logliksswap, states1, states0, signals, covs1, covs0 =load_data_discrimination(itraj=10, total_time = total_time, dt=dt, exp_path = exp_path)

pars = give_def_params_discrimination(flip=0, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)
[gamma1, omega1, n1, eta1, kappa1], [gamma0, omega0, n0, eta0, kappa0] = params

# %%
logliks

# %%
diff = logliksswap[:,0] - logliksswap[:,1]
ax = plt.subplot(111)
ax.plot(times, (logliks[:,1] - logliks[:,0])[:-1], label=r'$\ell_{|H1}$')
ax.plot(times, (logliksswap[:,0] - logliksswap[:,1])[:-1], label=r'$-\ell_{|H0}$')

# %%
pars = give_def_params_discrimination(flip=0, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)

total_time, dt = get_total_time_dt(params, ppp=1e3)
times, logliks, states1, states0, signals, covs1, covs0 =load_data_discrimination(itraj=10, total_time = total_time, dt=dt, exp_path = exp_path)

pars = give_def_params_discrimination(flip=1, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)

total_time, dt = get_total_time_dt(params, ppp=1e3)
times, logliksswap, states1, states0, signals, covs1, covs0 =load_data_discrimination(itraj=10, total_time = total_time, dt=dt, exp_path = exp_path)

pars = give_def_params_discrimination(flip=0, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)
[gamma1, omega1, n1, eta1, kappa1], [gamma0, omega0, n0, eta0, kappa0] = params
# Out:
# FREQUENCY DISCRIMINATION!

# %%
diff = logliksswap[:,0] - logliksswap[:,1]
plt.plot(times,diff[:-1])

# %%
plt.figure(figsize=(10,10))
plt.title(r'$(\omega_1, \omega_0) $' +"= ({}, {})".format(omega1, omega0) )
plt.suptitle(r'$(\eta, \kappa, n, \gamma)$'+"= ({}, {}, {})".format(eta1, kappa1, n1, gamma1))
ax = plt.subplot(111)
ax.plot(times, (logliks[:,1] - logliks[:,0])[:-1], label=r'$\ell_{|H1}$')
ax.plot(times, -(logliksswap[:,0] - logliksswap[:,1])[:-1], label=r'$-\ell_{|H0}$')

ax.set_xlabel("time")
ax.set_ylabel("likelihood ratio")
ax.set_yscale("log")

ax.legend(prop={"size":20})
# Out:
# /nfs/pic.es/user/m/mbilkis/qenv_bilkis/lib64/python3.6/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
times = load_data(ppp=ppp, periods=periods,method=method, itraj=itraj, exp_path=exp_path , rppp = rppp_reference)

# %%
ppp*(times[1]-times[0])/(2*np.pi)
# Out:
# 9.999999558922882e-05

# %%
times[1:] - times[:-1]
# Out:
# array([6.2831850e-07, 6.2831850e-07, 6.2831862e-07, ..., 6.3329935e-07,
#        6.2584877e-07, 6.2584877e-07], dtype=float32)

# %% [markdown]
# Another set

# %%
pars = give_def_params_discrimination(flip=0, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)

total_time, dt = get_total_time_dt(params, ppp=1e3)
times, logliks, states1, states0, signals, covs1, covs0 =load_data_discrimination(itraj=10, total_time = total_time, dt=dt, exp_path = exp_path)

pars = give_def_params_discrimination(flip=1, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)

total_time, dt = get_total_time_dt(params, ppp=1e3)
times, logliksswap, states1, states0, signals, covs1, covs0 =load_data_discrimination(itraj=10, total_time = total_time, dt=dt, exp_path = exp_path)

pars = give_def_params_discrimination(flip=0, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)
[gamma1, omega1, n1, eta1, kappa1], [gamma0, omega0, n0, eta0, kappa0] = params


plt.figure(figsize=(10,10))
plt.title(r'$(\omega_1, \omega_0) $' +"= ({}, {})".format(omega1, omega0) )
plt.suptitle(r'$(\eta, \kappa, n, \gamma)$'+"= ({}, {}, {})".format(eta1, kappa1, n1, gamma1))
ax = plt.subplot(111)
ax.plot(times, (logliks[:,1] - logliks[:,0])[:-1], label=r'$\ell_{|H1}$')
ax.plot(times, -(logliksswap[:,0] - logliksswap[:,1])[:-1], label=r'$-\ell_{|H0}$')

ax.set_xlabel("time")
ax.set_ylabel("likelihood ratio")
#ax.set_yscale("log")

ax.legend(prop={"size":20})
# Out:
# FREQUENCY DISCRIMINATION!
#
# FREQUENCY DISCRIMINATION!
#
# FREQUENCY DISCRIMINATION!
# /nfs/pic.es/user/m/mbilkis/qenv_bilkis/lib64/python3.6/site-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
pars = give_def_params_discrimination(flip=0, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)

total_time, dt = get_total_time_dt(params, ppp=1e3)
times, logliks, states1, states0, signals, covs1, covs0 =load_data_discrimination(itraj=10, total_time = total_time, dt=dt, exp_path = exp_path)

pars = give_def_params_discrimination(flip=1, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)

total_time, dt = get_total_time_dt(params, ppp=1e3)
times, logliksswap, states1, states0, signals, covs1, covs0 =load_data_discrimination(itraj=10, total_time = total_time, dt=dt, exp_path = exp_path)

pars = give_def_params_discrimination(flip=0, mode="frequencies") ## H0 is the true hypothesis
params, exp_path = check_params(pars)
[gamma1, omega1, n1, eta1, kappa1], [gamma0, omega0, n0, eta0, kappa0] = params


plt.figure(figsize=(10,10))
plt.title(r'$(\omega_1, \omega_0) $' +"= ({}, {})".format(omega1, omega0) )
plt.suptitle(r'$(\eta, \kappa, n, \gamma)$'+"= ({}, {}, {})".format(eta1, kappa1, n1, gamma1))
ax = plt.subplot(111)
ax.plot(times, (logliks[:,1] - logliks[:,0])[:-1], label=r'$\ell_{|H1}$')
ax.plot(times, -(logliksswap[:,0] - logliksswap[:,1])[:-1], label=r'$-\ell_{|H0}$')

ax.set_xlabel("time")
ax.set_ylabel("likelihood ratio")
#ax.set_yscale("log")

ax.legend(prop={"size":20})
# Out:
# FREQUENCY DISCRIMINATION!
#
# FREQUENCY DISCRIMINATION!
#
# FREQUENCY DISCRIMINATION!
# /nfs/pic.es/user/m/mbilkis/qenv_bilkis/lib64/python3.6/site-packages/ipykernel_launcher.py:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
