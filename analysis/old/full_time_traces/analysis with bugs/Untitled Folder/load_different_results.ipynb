# %%
import matplotlib.pyplot as plt
import os 
os.chdir("..")

# %%
import numpy as np

# %%
from numerics.utilities.misc import *

# %%
pf = get_def_path(mode="continuous")+"fre_discrimination/"

alpha_deter = np.load(pf+"alpha_deter.npy")
beta_deter = np.load(pf+"beta_deter.npy")
plt.plot(alpha_deter)
plt.plot(beta_deter)

# %%
pf = "analysis/data/damping_discrimination/set3LARGE/"

alpha_deter = np.load(pf+"alpha_deter.npy", allow_pickle=True)
beta_deter = np.load(pf+"beta_deter.npy", allow_pickle=True)
#plt.plot(alpha_deter)
#plt.plot(beta_deter)
alpha_deter
# Out:
# array({0: [0.6055045871559628, 0.6106014271151882, 0.6095820591233438, 0.6156982670744133, 0.6156982670744144, 0.6156982670744138, 0.6055045871559633, 0.6167176350662594, 0.6065239551478087, 0.5993883792048935, 0.5820591233435264, 0.5616717635066258, 0.5443425076452602, 0.5270132517838939, 0.5290519877675844, 0.5086646279306829, 0.5127420998980639, 0.4841997961264014, 0.478083588175331, 0.4556574923547397, 0.4587155963302758, 0.44036697247706413, 0.42201834862385323, 0.3883792048929667, 0.38328236493374124, 0.37614678899082576, 0.3577981651376143, 0.33537206931702324, 0.33129459734964356, 0.3088685015290527, 0.2976554536187569, 0.2691131498470952, 0.25790010193679946, 0.24057084607543308, 0.22528032619775723, 0.202854230377166, 0.19062181447502557, 0.16615698267074422, 0.1416921508664629, 0.11824668705402656, 0.08868501529051986, 0.07747196738022412, 0.055045871559633, 0.03975535168195718, 0.030581039755351636, 0.014271151885830802, 0.00815494393476046, 0.0050968399592252805, 0.00101
# ...

# %%
pf = "analysis/plot_data_stopping_time/"

gp1 = np.load(pf+"gp1.npy", allow_pickle=True)
stop_time = np.load(pf+"stopp_time_1K.npy", allow_pickle=True)
bins = np.load(pf+"stopp_time_1K_bins.npy", allow_pickle=True)

#plt.plot(alpha_deter)
#plt.plot(beta_deter)

# %%
plt.plot(bins[1:],stop_time)
plt.plot(np.linspace(0,4,len(gp1)),gp1)
