# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
means = np.load("data/means.npy").astype(np.float32)
covs = np.load("data/covs.npy").astype(np.float32)
xicovs = np.load("data/xicovs.npy").astype(np.float32)
signals = np.load("data/signals.npy").astype(np.float32)
A = np.load("data/A.npy").astype(np.float32)
dt = np.load("data/dt.npy")[0]
C = np.load("data/C.npy").astype(np.float32)
D = np.load("data/D.npy").astype(np.float32)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
from tqdm import tqdm
from misc import *
from RNN import *
import tensorflow as tf
# %load_ext autoreload
# %autoreload 2

coeffs = [C,A,D, dt]
model = ModelA(coeffs)
model.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-2), loss="mse")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
gru_layer = tf.keras.layers.GRU(2, return_sequences=True, stateful=True)
batched_signals = tf.stack(tf.split(tfsignals[:,:500,:][0], 5), axis=0)

# %%
gru_layer(batched_signals,ba)
# Out:
# <tf.Tensor: shape=(5, 100, 2), dtype=float32, numpy=
# array([[[-1.13732216e-03,  3.81916016e-03],
#         [-1.18796313e-02, -2.71169422e-03],
#         [ 3.25860688e-03, -1.50289861e-02],
#         [ 3.81425163e-03, -1.01158749e-02],
#         [-1.52984057e-02,  2.71791266e-03],
#         [ 1.57910064e-02, -5.48737682e-03],
#         [-9.40928236e-04, -2.64898385e-03],
#         [ 4.09914134e-03,  2.68863747e-03],
#         [ 7.10491510e-03,  8.45778966e-04],
#         [ 1.31922821e-02, -2.46301899e-03],
#         [ 6.75180927e-05, -1.22406182e-03],
#         [ 6.73200190e-03,  9.03045351e-04],
#         [ 6.47921115e-03,  9.93954577e-03],
#         [ 1.03364768e-03, -2.25849636e-03],
#         [-6.07782276e-03, -1.97820868e-02],
#         [-8.65549129e-03, -1.71811245e-02],
#         [-1.04563795e-02, -1.40793929e-02],
#         [-2.30783410e-03, -1.08047053e-02],
#         [-1.77913439e-03,  4.87654936e-04],
#         [ 1.42378435e-02,  8.77820014e-04],
# ...

# %%
from RNN import *

#batched_signals = tf.stack(tf.split(tfsignals[:,,:][0], 1000), axis=0)
batched_signals = tf.stack(tf.split(tfsignals[0], 100), axis=0)

model = ModelA(coeffs)
model.compile(optimizer=tf.keras.optimizers.Adam(lr=1e-2), loss="mse")

model(batched_signals)
model.fit(x =batched_signals, y = batched_signals, batch_size=len(batched_signals), epochs=100)
# Out:
# Epoch 1/100
# TensorShape([100, 400, 2])
# 1/1 [==============================] - 0s 841us/step - total_loss: 6.0523e-04
# Epoch 2/100
# TensorShape([100, 400, 2])
# 1/1 [==============================] - 0s 1ms/step - total_loss: 6.0523e-04
# Epoch 3/100
# TensorShape([100, 400, 2])
# 1/1 [==============================] - 0s 946us/step - total_loss: 6.0522e-04
# Epoch 4/100
# TensorShape([100, 400, 2])
# 1/1 [==============================] - 0s 983us/step - total_loss: 6.0522e-04
# Epoch 5/100
# TensorShape([100, 400, 2])
# 1/1 [==============================] - 0s 786us/step - total_loss: 6.0521e-04
# Epoch 6/100
# TensorShape([100, 400, 2])
# 1/1 [==============================] - 0s 821us/step - total_loss: 6.0521e-04
# Epoch 7/100
# TensorShape([100, 400, 2])
# 1/1 [==============================] - 0s 802us/step - total_loss: 6.0520e-04
# Epoch 8/100
# TensorShape([100, 400, 2])
# 1/1 [==============================] - 0s 765us/step - total_loss: 6.0519e-04
# Epoch 9/100
# ...

# %%
batched_signals = tf.stack(tf.split(tfsignals[0], 100), axis=0)

# %%
with tf.GradientTape() as tape:
    tape.watch(model.trainable_variables)
    states = model(batched_signals)
    Cxdt = tf.einsum('ij,btj->bti',C, states)*model.dt
    loss = tf.keras.losses.MeanSquaredError()(Cxdt, batched_signals)
grads = tape.gradient(loss, model.trainable_variables)
model.optimizer.apply_gradients(zip(grads, model.trainable_variables))
# Out:
# <tf.Variable 'UnreadVariable' shape=() dtype=int64, numpy=1>

# %%
with tf.GradientTape() as tape:
    tape.watch(model.trainable_variables)
    states = model(tfsignals)
    Crep = tf.repeat(tf.expand_dims(C, axis=0),tfsignals.shape[1], axis=0)
    Cxdt = tf.einsum('tij,btj->bti',Crep,states)*dt
    loss = tf.keras.losses.MeanSquaredError()(Cxdt, tfsignals)
grads = tape.gradient(loss, model.trainable_variables)
model.optimizer.apply_gradients(zip(grads, model.trainable_variables))
# Out:
# <tf.Variable 'UnreadVariable' shape=() dtype=int64, numpy=3>

# %%
# Out:
# [None, None, None]

# %%
A_pred = self.spit_A()
dx0 = A_pred - tf.einsum('tij,jl->til',self.tfxicovs[:-1], self.C)
dx1 = tf.einsum('tij,tj->ti', dx0, self.tfmeans[:-1])*self.dt
dx2 = dx1 + tf.einsum('tik,tk->ti', self.tfxicovs[:-1], self.tfsignals)
x = dx2 + self.tfmeans[:-1]    #this gives tfmeansx[1:]
lt1 = tf.einsum('ij,tj->ti',self.C,x)*self.dt
loss = tf.keras.losses.MeanSquaredError()(lt1[:-1], self.tfsignals[1:])
# Out:
# ListWrapper([InputSpec(shape=[None, 1], ndim=2)])
