# %%
# %load_ext autoreload
# %autoreload 2




import numpy as np
from misc import *
import matplotlib.pyplot as plt
from analyze import *

# %%
periods, ppp, itraj = 40, 500, 0

# %%
histories={}
for k in range(8):
    #hist_A, hist_loss, hist_grads
    try:
        histories[k] = load_train_results(periods=periods, ppp=ppp, train_id=k)
    except Exception:
        pass

# %%
histories.keys()
# Out:
# dict_keys([0])

# %%
lrs = {ind:k for ind,k in enumerate(np.logspace(-4,1,10))}

# %%
lrs
# Out:
# {0: 0.0001,
#  1: 0.00035938136638046257,
#  2: 0.001291549665014884,
#  3: 0.004641588833612782,
#  4: 0.016681005372000592,
#  5: 0.05994842503189409,
#  6: 0.21544346900318845,
#  7: 0.7742636826811278,
#  8: 2.782559402207126,
#  9: 10.0}

# %%
fig_size=(10,10)
fig = plt.figure(figsize=fig_size)

fig = display_histories(fig,histories)

# %%
for k in list(histories.keys()):
    print(histories[k][0][-1], "\n")
# Out:
# [[6.2873235]]

# %%
plt.plot(np.squeeze(histories[k][0]))
plt.plot([0,len(histories[k][0])], [np.pi*2]*2,'--', color="black")
plt.xlabel('gradient descent it')
plt.ylabel("parameter")
# Out:
# Text(0, 0.5, 'parameter')

# %%
means, covs, signals, coeffs = load_data(get_def_path()+"{}periods/{}ppp/".format(periods,ppp))

# %%
A, dt, C, D = coeffs

# %%
A
# Out:
# array([[ 0.       ,  6.2831855],
#        [-6.2831855,  0.       ]], dtype=float32)
