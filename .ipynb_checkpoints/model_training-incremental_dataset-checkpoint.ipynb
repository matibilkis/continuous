# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
from tqdm import tqdm
from misc import *
import tensorflow as tf
# %load_ext autoreload
# %autoreload 2


means = np.load("data/means.npy").astype(np.float32) ### this is \textbf{q}(t)
covs = np.load("data/covs.npy").astype(np.float32) ## this is the \Sigma(t)
xicovs = np.load("data/xicovs.npy").astype(np.float32) ## this is the \Chi(\Sigma) (evolution)
signals = np.load("data/signals.npy").astype(np.float32) ##this is the dy's

A = np.load("data/A.npy").astype(np.float32)
dt = np.load("data/dt.npy")[0]
C = np.load("data/C.npy").astype(np.float32)
D = np.load("data/D.npy").astype(np.float32)

coeffs = [C, A, D , dt]

plt.figure(figsize=(10,10))
plt.subplot(221)
plt.title(r'$\vec{x}(t)$')
for ind, c in enumerate(["red","blue"]):
    plt.plot(np.array(means)[:,ind], color=c)
plt.subplot(222)
plt.title(r'$d\vec{y}(t)$')
for ind, c in enumerate(["red","blue"]):
    plt.plot(np.array(signals)[:,ind], color=c, linewidth=0.05)
# Out:
# <style>.container { width:100% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def sliced_dataset(t):
    tfsignals = tf.convert_to_tensor(signals)[:t] ## this are dy's
    tfxicovs = tf.convert_to_tensor(xicovs)[:-1][:t] ### since we get (\mu_t, \Sigma_t) ---> Measurement ( = signal) ---> (\mu_{t+1}, \Sigma_{t+1})
    return (tfxicovs[tf.newaxis,:,:,:], tfsignals[tf.newaxis,:,:])

# %%
from RNN_models import *

model = GaussianRecuModel(coeffs)
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.1))

# %%
time_slice = len(signals)
inputs = sliced_dataset(time_slice)
model.fit(x=inputs, y=inputs[1][tf.newaxis,:,:], epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 677us/step - total_loss: 0.0035
# Epoch 2/100
# 1/1 [==============================] - 0s 658us/step - total_loss: 0.0035
# Epoch 3/100
# 1/1 [==============================] - 0s 688us/step - total_loss: 0.0034
# Epoch 4/100
# 1/1 [==============================] - 0s 685us/step - total_loss: 0.0034
# Epoch 5/100
# 1/1 [==============================] - 0s 781us/step - total_loss: 0.0034
# Epoch 6/100
# 1/1 [==============================] - 0s 766us/step - total_loss: 0.0034
# Epoch 7/100
# 1/1 [==============================] - 0s 787us/step - total_loss: 0.0034
# Epoch 8/100
# 1/1 [==============================] - 0s 749us/step - total_loss: 0.0034
# Epoch 9/100
# 1/1 [==============================] - 0s 874us/step - total_loss: 0.0034
# Epoch 10/100
# 1/1 [==============================] - 0s 926us/step - total_loss: 0.0033
# Epoch 11/100
# 1/1 [==============================] - 0s 899us/step - total_loss: 0.0033
# Epoch 12/100
# 1/1 [==============================] - 0s 872us/step - total_loss: 0.0033
# Epoch 13/100
# 1/1 [==============================] - 0s 871us/step - total_loss: 0.0033
# Epoch 14/100
# 1/1 [==============================] - 0s 859us/step - total_loss: 0.0033
# Epoch 15/100
# 1/1 [==============================] - 0s 874us/step - total_loss: 0.0033
# Epoch 16/100
# 1/1 [==============================] - 0s 866us/step - total_loss: 0.0033
# Epoch 17/100
# 1/1 [==============================] - 0s 931us/step - total_loss: 0.0033
# Epoch 18/100
# 1/1 [==============================] - 0s 891us/step - total_loss: 0.0034
# Epoch 19/100
# 1/1 [==============================] - 0s 928us/step - total_loss: 0.0033
# Epoch 20/100
# 1/1 [==============================] - 0s 872us/step - total_loss: 0.0033
# Epoch 21/100
# 1/1 [==============================] - 0s 905us/step - total_loss: 0.0033
# Epoch 22/100
# 1/1 [==============================] - 0s 936us/step - total_loss: 0.0033
# Epoch 23/100
# 1/1 [==============================] - 0s 892us/step - total_loss: 0.0033
# Epoch 24/100
# 1/1 [==============================] - 0s 893us/step - total_loss: 0.0033
# Epoch 25/100
# 1/1 [==============================] - 0s 860us/step - total_loss: 0.0033
# Epoch 26/100
# 1/1 [==============================] - 0s 866us/step - total_loss: 0.0033
# Epoch 27/100
# 1/1 [==============================] - 0s 891us/step - total_loss: 0.0033
# Epoch 28/100
# 1/1 [==============================] - 0s 863us/step - total_loss: 0.0033
# Epoch 29/100
# 1/1 [==============================] - 0s 870us/step - total_loss: 0.0033
# Epoch 30/100
# 1/1 [==============================] - 0s 880us/step - total_loss: 0.0033
# Epoch 31/100
# 1/1 [==============================] - 0s 865us/step - total_loss: 0.0033
# Epoch 32/100
# 1/1 [==============================] - 0s 919us/step - total_loss: 0.0033
# Epoch 33/100
# 1/1 [==============================] - 0s 1ms/step - total_loss: 0.0033
# Epoch 34/100
# 1/1 [==============================] - 0s 859us/step - total_loss: 0.0033
# Epoch 35/100
# 1/1 [==============================] - 0s 898us/step - total_loss: 0.0033
# Epoch 36/100
# 1/1 [==============================] - 0s 890us/step - total_loss: 0.0033
# Epoch 37/100
# 1/1 [==============================] - 0s 864us/step - total_loss: 0.0033
# Epoch 38/100
# 1/1 [==============================] - 0s 868us/step - total_loss: 0.0033
# Epoch 39/100
# 1/1 [==============================] - 0s 962us/step - total_loss: 0.0033
# Epoch 40/100
# 1/1 [==============================] - 0s 864us/step - total_loss: 0.0033
# Epoch 41/100
# 1/1 [==============================] - 0s 891us/step - total_loss: 0.0033
# Epoch 42/100
# 1/1 [==============================] - 0s 866us/step - total_loss: 0.0033
# Epoch 43/100
# 1/1 [==============================] - 0s 892us/step - total_loss: 0.0033
# Epoch 44/100
# 1/1 [==============================] - 0s 892us/step - total_loss: 0.0033
# Epoch 45/100
# 1/1 [==============================] - 0s 859us/step - total_loss: 0.0033
# Epoch 46/100
# 1/1 [==============================] - 0s 921us/step - total_loss: 0.0033
# Epoch 47/100
# 1/1 [==============================] - 0s 890us/step - total_loss: 0.0033
# Epoch 48/100
# 1/1 [==============================] - 0s 887us/step - total_loss: 0.0033
# Epoch 49/100
# 1/1 [==============================] - 0s 897us/step - total_loss: 0.0033
# Epoch 50/100
# 1/1 [==============================] - 0s 961us/step - total_loss: 0.0033
# Epoch 51/100
# 1/1 [==============================] - 0s 865us/step - total_loss: 0.0033
# Epoch 52/100
# 1/1 [==============================] - 0s 860us/step - total_loss: 0.0033
# Epoch 53/100
# 1/1 [==============================] - 0s 881us/step - total_loss: 0.0033
# Epoch 54/100
# 1/1 [==============================] - 0s 915us/step - total_loss: 0.0033
# Epoch 55/100
# 1/1 [==============================] - 0s 907us/step - total_loss: 0.0033
# Epoch 56/100
# 1/1 [==============================] - 0s 892us/step - total_loss: 0.0033
# Epoch 57/100
# 1/1 [==============================] - 0s 869us/step - total_loss: 0.0033
# Epoch 58/100
# 1/1 [==============================] - 0s 860us/step - total_loss: 0.0033
# Epoch 59/100
# 1/1 [==============================] - 0s 868us/step - total_loss: 0.0033
# Epoch 60/100
# 1/1 [==============================] - 0s 882us/step - total_loss: 0.0033
# Epoch 61/100
# 1/1 [==============================] - 0s 900us/step - total_loss: 0.0033
# Epoch 62/100
# 1/1 [==============================] - 0s 892us/step - total_loss: 0.0033
# Epoch 63/100
# 1/1 [==============================] - 0s 949us/step - total_loss: 0.0033
# Epoch 64/100
# 1/1 [==============================] - 0s 865us/step - total_loss: 0.0033
# Epoch 65/100
# 1/1 [==============================] - 0s 1ms/step - total_loss: 0.0033
# Epoch 66/100
# 1/1 [==============================] - 0s 857us/step - total_loss: 0.0033
# Epoch 67/100
# 1/1 [==============================] - 0s 949us/step - total_loss: 0.0033
# Epoch 68/100
# 1/1 [==============================] - 0s 880us/step - total_loss: 0.0033
# Epoch 69/100
# 1/1 [==============================] - 0s 889us/step - total_loss: 0.0033
# Epoch 70/100
# 1/1 [==============================] - 0s 881us/step - total_loss: 0.0033
# Epoch 71/100
# 1/1 [==============================] - 0s 867us/step - total_loss: 0.0033
# Epoch 72/100
# 1/1 [==============================] - 0s 875us/step - total_loss: 0.0033
# Epoch 73/100
# 1/1 [==============================] - 0s 893us/step - total_loss: 0.0033
# Epoch 74/100
# 1/1 [==============================] - 0s 887us/step - total_loss: 0.0033
# Epoch 75/100
# 1/1 [==============================] - 0s 895us/step - total_loss: 0.0033
# Epoch 76/100
# 1/1 [==============================] - 0s 905us/step - total_loss: 0.0033
# Epoch 77/100
# 1/1 [==============================] - 0s 861us/step - total_loss: 0.0033
# Epoch 78/100
# 1/1 [==============================] - 0s 982us/step - total_loss: 0.0033
# Epoch 79/100
# 1/1 [==============================] - 0s 863us/step - total_loss: 0.0033
# Epoch 80/100
# 1/1 [==============================] - 0s 872us/step - total_loss: 0.0033
# Epoch 81/100
# 1/1 [==============================] - 0s 872us/step - total_loss: 0.0033
# Epoch 82/100
# 1/1 [==============================] - 0s 930us/step - total_loss: 0.0033
# Epoch 83/100
# 1/1 [==============================] - 0s 939us/step - total_loss: 0.0033
# Epoch 84/100
# 1/1 [==============================] - 0s 889us/step - total_loss: 0.0033
# Epoch 85/100
# 1/1 [==============================] - 0s 931us/step - total_loss: 0.0033
# Epoch 86/100
# 1/1 [==============================] - 0s 904us/step - total_loss: 0.0033
# Epoch 87/100
# 1/1 [==============================] - 0s 3ms/step - total_loss: 0.0033
# Epoch 88/100
# 1/1 [==============================] - 0s 1ms/step - total_loss: 0.0033
# Epoch 89/100
# 1/1 [==============================] - 0s 835us/step - total_loss: 0.0033
# Epoch 90/100
# 1/1 [==============================] - 0s 876us/step - total_loss: 0.0033
# Epoch 91/100
# 1/1 [==============================] - 0s 1ms/step - total_loss: 0.0033
# Epoch 92/100
# 1/1 [==============================] - 0s 854us/step - total_loss: 0.0033
# Epoch 93/100
# 1/1 [==============================] - 0s 820us/step - total_loss: 0.0033
# Epoch 94/100
# 1/1 [==============================] - 0s 1ms/step - total_loss: 0.0033
# Epoch 95/100
# 1/1 [==============================] - 0s 804us/step - total_loss: 0.0033
# Epoch 96/100
# 1/1 [==============================] - 0s 1ms/step - total_loss: 0.0033
# Epoch 97/100
# 1/1 [==============================] - 0s 1ms/step - total_loss: 0.0033
# Epoch 98/100
# 1/1 [==============================] - 0s 1ms/step - total_loss: 0.0033
# Epoch 99/100
# 1/1 [==============================] - 0s 828us/step - total_loss: 0.0033
# Epoch 100/100
# 1/1 [==============================] - 0s 889us/step - total_loss: 0.0033

# %%
model.trainable_variables
# Out:
# [<tf.Variable 'gaussian_recu_model_31/rnn_32/stacked_rnn_cells_33/gaussian_dynamics__recurrent_cell_33/kernel:0' shape=(2, 2) dtype=float32, numpy=
#  array([[-0.00415921,  0.9757078 ],
#         [-0.9865686 , -0.04448316]], dtype=float32)>]

# %%
# Out:
#  33%|███▎      | 206/619 [00:59<01:59,  3.45it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-e288944ec65b> in <module>
#       2 for time_slice in tqdm(range(10,len(signals),10)):#[int(k) for k in np.logspace(1, np.log10(len(signals)), 20)]):
#       3     inputs = sliced_dataset(time_slice)
# ----> 4     model.fit(x=inputs, y=inputs[1][tf.newaxis,:,:], epochs=2, verbose=v(time_slice))
#       5     #print("Enlarging the training set...\n")
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     812       # In this case we have not created variables on the first call. So we can
#     813       # run the first trace but we should fail if variables are created.
# --> 814       results = self._stateful_fn(*args, **kwds)
#     815       if self._created_variables:
#     816         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
series = ( tfxicovs[tf.newaxis,:,:,:], tfsignals[tf.newaxis,:,:] )
model.batch_size=1
predictions = model.recurrent_layer(series, initial_state=model.initial_state)
tfmeans = tf.convert_to_tensor(means.astype(np.float32))
Cxdt=tf.einsum('ij,kj->ki',model.C, tfmeans)*model.dt

# %%
plt.figure(figsize=(10,10))

#plt.title("Learning stochastic time-series")
plt.suptitle(r'$ dx = (A - \chi(\Sigma))x dt + \chi(\Sigma) dy$' +
             "\n" r'$dy =  C x dt + dW$'+ "\n" +
             r'$ d\hat{x} = (A_\theta - \chi(\Sigma))\hat{x} dt + \chi(\Sigma) dy$'
            + "\n" + r'$\dot{\Sigma} = A \Sigma + \Sigma A^\dagger + \Lambda - \chi(\Sigma) \chi^\dagger(\Sigma)$')
plt.plot(predictions[0][:,0], color="blue", alpha=0.5, linewidth=5, label=r'$C \hat{x}(t) dt$')
plt.plot(Cxdt[:,0][:10000], color="red", alpha=0.8,label=r'$C x(t) dt$', linewidth=5)
plt.legend(prop={"size":30})
plt.xlabel("time", size=30)
# Out:
# Text(0.5, 0, 'time')

# %%
plt.figure(figsize=(10,10))

#plt.title("Learning stochastic time-series")
plt.suptitle(r'$ dx = (A - \chi(\Sigma))x dt + \chi(\Sigma) dy$' +
             "\n" r'$dy =  C x dt + dW$'+ "\n" +
             r'$ d\hat{x} = (A_\theta - \chi(\Sigma))\hat{x} dt + \chi(\Sigma) dy$'
            + "\n" + r'$\dot{\Sigma} = A \Sigma + \Sigma A^\dagger + \Lambda - \chi(\Sigma) \chi^\dagger(\Sigma)$')
plt.plot(predictions[0][:,0], color="blue", alpha=0.5, linewidth=5, label=r'$C \hat{x}(t) dt$')
plt.plot(Cxdt[:,0][:10000], color="red", alpha=0.8,label=r'$C x(t) dt$', linewidth=5)
plt.legend(prop={"size":30})
plt.xlabel("time", size=30)
# Out:
# Text(0.5, 0, 'time')

# %%
# Out:
# [<tf.Variable 'rnn_1/stacked_rnn_cells_1/minimal_rnn_cell_1/kernel:0' shape=(2, 2) dtype=float32, numpy=
#  array([[ 0.00503228, -0.01521729],
#         [ 0.01534598,  0.01874068]], dtype=float32)>,
#  <tf.Variable 'rnn_1/stacked_rnn_cells_1/minimal_rnn_cell_1/recurrent_kernel:0' shape=(2, 2) dtype=float32, numpy=
#  array([[-0.00112511,  0.01087658],
#         [-0.03937121, -0.02510941]], dtype=float32)>]

# %%
model.A
# Out:
# array([[ 0.  ,  1.  ],
#        [-0.16,  0.  ]], dtype=float32)

# %%
plt.figure(figsize=(10,10))

#plt.title("Learning stochastic time-series")
plt.suptitle(r'$ dx = (A - \chi(\Sigma))x dt + \chi(\Sigma) dy$' +
             "\n" r'$dy =  C x dt + dW$'+ "\n" +
             r'$ d\hat{x} = (A_\theta - \chi(\Sigma))\hat{x} dt + \chi(\Sigma) dy$'
            + "\n" + r'$\dot{\Sigma} = A \Sigma + \Sigma A^\dagger + \Lambda - \chi(\Sigma) \chi^\dagger(\Sigma)$')
plt.plot(predictions[0][:,0], color="blue", alpha=0.5, linewidth=5, label=r'$C \hat{x}(t) dt$')
plt.plot(Cxdt[:,0][:10000], color="red", alpha=0.8,label=r'$C x(t) dt$', linewidth=5)
plt.legend(prop={"size":30})
plt.xlabel("time", size=30)
# Out:
# Text(0.5, 0, 'time')
