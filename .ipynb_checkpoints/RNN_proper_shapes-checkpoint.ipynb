# %%
from IPython.core.display import display, HTML

import numpy as np
means = np.load("data/means.npy").astype(np.float32)
covs = np.load("data/covs.npy").astype(np.float32)
xicovs = np.load("data/xicovs.npy").astype(np.float32)
signals = np.load("data/signals.npy").astype(np.float32)
A = np.load("data/A.npy").astype(np.float32)
dt = np.load("data/dt.npy")[0]
C = np.load("data/C.npy").astype(np.float32)
D = np.load("data/D.npy").astype(np.float32)

coeffs = [C, A, D , dt]



from scipy.stats import norm
import matplotlib.pyplot as plt
from tqdm import tqdm
from misc import *
import tensorflow as tf
# %load_ext autoreload
# %autoreload 2

tfsignals = tf.convert_to_tensor(signals)
tfxicovs = tf.convert_to_tensor(xicovs)[:-1]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
batched_signals = tf.stack(tf.split(tfsignals, 100)) 
batched_xicovs  = tf.stack(tf.split(tfxicovs, 100))

inputs = (batched_xicovs, batched_signals)

# %%
plt.plot(preds[0,:,0])
plt.plot(means[1:,0][:len(preds[0])],color="black")

# %%
inputs = (batched_xicovs, batched_signals)
# Out:
# TensorShape([100, 400, 2])

# %%
model(inputs)
# Out:
# inputs:  (100, 2, 2) ... (100, 2)
#
#
# states:  [TensorShape([1, 2])]
# ***
#
#
# (1, 2)
# (100, 2, 2)
# inputs:  (100, 2, 2) ... (100, 2)
#
#
# states:  [TensorShape([1, 2])]
# ***
#
#
# (1, 2)
# (100, 2, 2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-8116aa0b6757> in <module>
# ----> 1 model(inputs)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/continuous/RNN_models.py in call(self, inputs)
#      56
#      57     def call(self, inputs):
# ---> 58         f = self.rec_layer(inputs, initial_state = self.init_state)
#      59         return f
#      60
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     714       if constants is not None:
#     715         kwargs['constants'] = constants
# --> 716       return super(RNN, self).__call__(inputs, **kwargs)
#     717
#     718   def call(self,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state, constants)
#     801         input_length=row_lengths if row_lengths is not None else timesteps,
#     802         time_major=self.time_major,
# --> 803         zero_output_for_mask=self.zero_output_for_mask)
#     804
#     805     if self.stateful:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask)
#    4359           body=_step,
#    4360           loop_vars=(time, output_ta) + states,
# -> 4361           **while_loop_kwargs)
#    4362       new_states = final_outputs[2:]
#    4363
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2733                                               list(loop_vars))
#    2734       while cond(*loop_vars):
# -> 2735         loop_vars = body(*loop_vars)
#    2736         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2737           packed = True
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in _step(time, output_ta_t, *states)
#    4348         for state, new_state in zip(flat_state, flat_new_state):
#    4349           if isinstance(new_state, ops.Tensor):
# -> 4350             new_state.set_shape(state.shape)
#    4351
#    4352         flat_output = nest.flatten(output)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in set_shape(self, shape)
#    1207       raise ValueError(
#    1208           "Tensor's shape %s is not compatible with supplied shape %s" %
# -> 1209           (self.shape, shape))
#    1210
#    1211   # Methods not supported / implemented for Eager Tensors.
#
# ValueError: Tensor's shape (100, 2) is not compatible with supplied shape (1, 2)

# %%
from RNN_models import *

model = RecModel(coeffs)
preds = model(inputs)
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.01))

model.fit(x=inputs, y=batched_signals, epochs=1000)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-188-e803f247a4e5> in <module>
#       2
#       3 model = RecModel(coeffs)
# ----> 4 preds = model(inputs)
#       5 model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.01))
#       6
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/continuous/RNN_models.py in call(self, inputs)
#      52
#      53     def call(self, inputs):
# ---> 54         f = self.rec_layer(inputs, initial_state = self.init_state)
#      55         return f
#      56
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     714       if constants is not None:
#     715         kwargs['constants'] = constants
# --> 716       return super(RNN, self).__call__(inputs, **kwargs)
#     717
#     718   def call(self,
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in call(self, inputs, mask, training, initial_state, constants)
#     801         input_length=row_lengths if row_lengths is not None else timesteps,
#     802         time_major=self.time_major,
# --> 803         zero_output_for_mask=self.zero_output_for_mask)
#     804
#     805     if self.stateful:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask)
#    4212     # the value is discarded.
#    4213     output_time_zero, _ = step_function(
# -> 4214         input_time_zero, tuple(initial_states) + tuple(constants))
#    4215     output_ta = tuple(
#    4216         tensor_array_ops.TensorArray(
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in step(inputs, states)
#     787       def step(inputs, states):
#     788         states = states[0] if len(states) == 1 and is_tf_rnn_cell else states
# --> 789         output, new_states = cell_call_fn(inputs, states, **kwargs)
#     790         if not nest.is_sequence(new_states):
#     791           new_states = [new_states]
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/layers/recurrent.py in call(self, inputs, states, constants, training, **kwargs)
#     154                                       constants=constants, **kwargs)
#     155       else:
# --> 156         inputs, states = cell_call_fn(inputs, states, **kwargs)
#     157       new_nested_states.append(states)
#     158
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     983
#     984         with ops.enable_auto_cast_variables(self._compute_dtype_object):
# --> 985           outputs = call_fn(inputs, *args, **kwargs)
#     986
#     987         if self._activity_regularizer:
#
# ~/continuous/RNN_models.py in call(self, inputs, states)
#      36         batched_xicovs, dy = inputs
#      37         batched_A_minus_xiC = self.coeffs_A - tf.einsum('bij,jk->bik',batched_xicovs,self.C)
# ---> 38         dx = tf.einsum('bij,bj->bi',batched_A_minus_xiC, prev_output)*self.dt + tf.einsum('bij,bj->bi', batched_xicovs, dy)
#      39         x = prev_output + dx
#      40         output = tf.einsum('ij,bj->bi',self.C, prev_output)*self.dt
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/special_math_ops.py in einsum(equation, *inputs, **kwargs)
#     682       - number of inputs or their shapes are inconsistent with `equation`.
#     683   """
# --> 684   return _einsum_v2(equation, *inputs, **kwargs)
#     685
#     686
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/special_math_ops.py in _einsum_v2(equation, *inputs, **kwargs)
#    1111       if ellipsis_label:
#    1112         resolved_equation = resolved_equation.replace(ellipsis_label, '...')
# -> 1113       return gen_linalg_ops.einsum(inputs, resolved_equation)
#    1114
#    1115     # Send fully specified shapes to opt_einsum, since it cannot handle unknown
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/ops/gen_linalg_ops.py in einsum(inputs, equation, name)
#    1086       return _result
#    1087     except _core._NotOkStatusException as e:
# -> 1088       _ops.raise_from_not_ok_status(e, name)
#    1089     except _core._FallbackException:
#    1090       pass
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# ~/.local/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Expected dimension 100 at axis 0 of the input shaped [1,2] but got dimension 1 [Op:Einsum]

# %%
model.trainable_variables
# Out:
# [<tf.Variable 'rec_model_44/rnn_42/stacked_rnn_cells_43/minimal_rnn_cell_43/coeffs_A:0' shape=(2, 2) dtype=float32, numpy=
#  array([[-304.82812 ,  -47.463505],
#         [ -66.58033 , -112.41691 ]], dtype=float32)>,
#  <tf.Variable 'rec_model_44/rnn_42/stacked_rnn_cells_43/minimal_rnn_cell_43/recurrent_kernel:0' shape=(2, 2) dtype=float32, numpy=
#  array([[ 0.02104327,  0.0097038 ],
#         [-0.04380789, -0.00040723]], dtype=float32)>]

# %%
model.A
# Out:
# array([[ 0.  ,  1.  ],
#        [-0.16,  0.  ]], dtype=float32)
