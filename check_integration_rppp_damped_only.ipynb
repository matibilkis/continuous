# %%
from misc import *
import matplotlib.pyplot as plt

periods = 100
ppp = 10000
rppp = 1
states = {}
states_euler = {}
rppps = [1,10,100,1000,10000,100000]
for rppp in rppps:

    states[rppp], covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(rppp), periods=periods, ppp=ppp, method="rossler")
    states_euler[rppp], covs_euler, signals_euler, params_euler, times_euler = load_data(path=get_def_path()+"rppp{}/".format(rppp), 
                                                                                   periods=periods, ppp=ppp, method="euler")
# Out:
# Traj loaded
# ppp: 10000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 10000
# periods: 100
# method: euler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 10000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 10000
# periods: 100
# method: euler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 10000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 10000
# periods: 100
# method: euler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 10000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 10000
# periods: 100
# method: euler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 10000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 10000
# periods: 100
# method: euler
# itraj: 1
# ...

# %%
a = 0
b = -1
plt.plot(states[1][:,0][a:b])
plt.plot(states_euler[1][:,0][a:b])

# %%
errs = {}
for rppp in rppps:
    errs[rppp] = np.sqrt(np.mean(np.square(states[1][::rppp] - states[rppp])))
ax = plt.subplot(111)
ax.plot(errs.keys(), errs.values(), '.')
ax.set_ylabel(r'$\sqrt{MSE}$')
ax.set_xlabel(r'$window \; size$')
ax.set_xscale("log")
ax.set_yscale("log")

# %% [markdown]
# Now not damped only but with freq! (only 1 period...)

# %%
windows = np.concatenate([(10**k)*np.arange(2,11) for k in range(5)])

# %%
periods = 1
ppp = 100000
rppp = 1
states = {}

states[1], covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(1), periods=periods, ppp=ppp, method="rossler")

for rppp in windows:
    try:
        states[rppp], covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(rppp), periods=periods, ppp=ppp, method="rossler")
    except Exception:
        pass
# Out:
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 1
# method: rossler
# itraj: 1
# ...

# %%
errs = {}
for rppp in list(states.keys())[:-1]:
    errs[rppp] = np.sqrt(np.mean(np.square(states[1][::rppp] - states[rppp])))
plt.title("ppp = {}\nperiods = {}\n".format(ppp,periods))
ax = plt.subplot(111)
ax.plot(errs.keys(), errs.values(), '.')
ax.set_ylabel(r'$\sqrt{MSE}$')
ax.set_xlabel(r'$window \; size$')
#ax.set_xscale("log")
#ax.set_yscale("log")
# Out:
# /home/cooper-cooper/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """
# Text(0.5, 0, '$window \\; size$')

# %%
errs = {}
for rppp in states.keys():
    errs[rppp] = np.sqrt(np.mean(np.square(states[1][::rppp] - states[rppp])))
plt.title("ppp = {}\nperiods = {}\n".format(ppp,periods))
ax = plt.subplot(111)
ax.plot(errs.keys(), errs.values(), '.')
ax.set_ylabel(r'$\sqrt{MSE}$')
ax.set_xlabel(r'$window \; size$')
ax.set_xscale("log")
ax.set_yscale("log")
# Out:
# /home/cooper-cooper/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %% [markdown]
# Now much more points (super long data set, with 100 periods)

# %%
periods = 100
ppp = 100000
rppp = 1
states = {}

windows = np.concatenate([(10**k)*np.arange(2,11) for k in range(6)])
method = "rossler"
for rppp in [1] + list(windows):
    try:
        
        states[rppp], covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(rppp), periods=periods, ppp=ppp, method="rossler")
    except Exception:
        pass
# Out:
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# Traj loaded
# ppp: 100000
# periods: 100
# method: rossler
# itraj: 1
# ...

# %%
errs = {}
for rppp in states.keys():
    errs[rppp] = np.sqrt(np.mean(np.square(states[4][::int(rppp/4)] - states[rppp][::4])))
plt.title("ppp = {}\nperiods = {}\n".format(ppp,periods))
ax = plt.subplot(111)
ax.plot(errs.keys(), errs.values(), '.')
ax.set_ylabel(r'$\sqrt{MSE}$')
ax.set_xlabel(r'$window \; size$')
ax.set_xscale("log")
ax.set_yscale("log")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-9bb9fe1a2a12> in <module>
#       1 errs = {}
#       2 for rppp in states.keys():
# ----> 3     errs[rppp] = np.sqrt(np.mean(np.square(states[4][::int(rppp/4)] - states[rppp][::4])))
#       4 plt.title("ppp = {}\nperiods = {}\n".format(ppp,periods))
#       5 ax = plt.subplot(111)
#
# ValueError: operands could not be broadcast together with shapes (2500000,2) (625000,2)

# %%
dt = 1/ppp

# %%
times = np.arange(0,periods+ dt, dt )

# %%
len(times)
# Out:
# 10000001

# %%
tspan = times[:-1]

# %%
(len(tspan) - (len(tspan) % 3)) %3
# Out:
# 0

# %%
rpp = 3
tspan_integer = tspan[:-(len(tspan)%rpp)]

# %%
tspan_integer[::rppp]
# Out:
# array([0.000000e+00, 4.000000e-05, 8.000000e-05, ..., 9.999988e+01,
#        9.999992e+01, 9.999996e+01])

# %%
states_euler
# Out:
# array([[ 1.       ,  0.       ],
#        [ 1.0229717,  0.       ],
#        [ 1.0270799,  0.       ],
#        ...,
#        [-4.0803714,  0.       ],
#        [-4.0705934,  0.       ],
#        [-4.0715494,  0.       ]], dtype=float32)

# %%
dt = 1/ppp
times = np.arange(0,periods+dt,dt)

# %%
r_ppp = 2

# %%
times
# Out:
# array([0.000e+00, 2.000e-03, 4.000e-03, ..., 9.996e+00, 9.998e+00,
#        1.000e+01])

# %%
times[::2]
# Out:
# array([0.000e+00, 4.000e-03, 8.000e-03, ..., 9.992e+00, 9.996e+00,
#        1.000e+01])

# %%
dw = np.random.randn(len(times[:-1]))
print("len_times_now : ",int(len(dw)/rr))
ddw = np.zeros(int(len(dw)/rr))

for sl in range(rr):
    ddw+=dw[sl::rr]
ddw/=np.sqrt(rr)
# Out:
# len_times_now :  1000

# %%
rppp = 5
states, covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(rppp), periods=5, ppp=1000)
# Out:
# Traj loaded
# ppp: 1000
# periods: 5
# method: rossler
# itraj: 1
# Unphyisical (testing): False

# %%
plt.plot(times[:-1][::rppp],states[:,0])

# %%
rppp = 1
states_1, covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(rppp), periods=5, ppp=1000, method="rossler")
# Out:
# Traj loaded
# ppp: 1000
# periods: 5
# method: rossler
# itraj: 1
# Unphyisical (testing): False

# %%
rppp = 50
states_50, covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(rppp), periods=5, ppp=1000, method="rossler")
# Out:
# Traj loaded
# ppp: 1000
# periods: 5
# method: rossler
# itraj: 1
# Unphyisical (testing): False

# %%
np.mean(np.square(states_50[:,0] - states_1[:,0][::50]))
# Out:
# 0.000738084

# %%
rppp = 5
states_5, covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(rppp), periods=5, ppp=1000, method="rossler")
# Out:
# Traj loaded
# ppp: 1000
# periods: 5
# method: rossler
# itraj: 1
# Unphyisical (testing): False

# %%
np.mean(np.square(states_5[:,0] - states_1[:,0][::5]))
# Out:
# 4.194923e-06

# %%
states = {}
for rppp in [1,10, 100]:
    states[rppp], covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(rppp), periods=5, ppp=1000, method="rossler")
# Out:
# Traj loaded
# ppp: 1000
# periods: 5
# method: rossler
# itraj: 1
# Unphyisical (testing): False
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-97-9d2616e51597> in <module>
#       2 for rppp in [1,10, 100]:
#       3
# ----> 4     states[rppp], covs, signals, params, times = load_data(path=get_def_path()+"rppp{}/".format(rppp), periods=5, ppp=1000, method="rossler")
#
# ~/Desktop/continuous/misc.py in load_data(path, itraj, ppp, periods, method, unphysical)
#      37     if unphysical is True:
#      38         path+="unphysical_"
# ---> 39     times = np.load(path+"times.npy", allow_pickle=True).astype(np.float32) ### this is \textbf{q}(t)
#      40     states = np.load(path+"states.npy", allow_pickle=True).astype(np.float32) ### this is \textbf{q}(t)
# ...

# %%
ppp=1000
periods = 5
dt = 1/ppp
plt.plot(np.arange(0,periods+dt, dt)[:-1][::5],states[:,0])
plt.plot(np.arange(0,periods+dt, dt)[:-1][::1],states_1[:,0])

# %%
states[:,0][::]

# %%
from misc import get_def_path, load_data
import numpy as np
import matplotlib.pyplot as plt

# %%
load_data(periods = periods)

# %%
periods = 100
ppp = 100
itraj = 1
method = "euler"
path = get_def_path()
path = path + "{}periods/{}ppp/{}/{}/".format(periods,ppp,method, itraj)
states_euler = np.load(path+"states.npy")
method = "rossler"
path = get_def_path() + "{}periods/{}ppp/{}/{}/".format(periods,ppp,method, itraj)
states_rossler = np.load(path+"states.npy")

# %%
states_rossler = np.load(path+"covs.npy")

# %%
states_rossler[-1]
# Out:
# array([[0.54194813, 0.        ],
#        [0.        , 2.42531938]])

# %%
plt.plot(states_rossler[:,0])

# %%
plt.figure(figsize=(30,10))
plt.suptitle("dt = 0.01", size=40)
plt.subplot(121)
plt.plot(states_rossler[:,0])
plt.plot(states_euler[:,0])
plt.subplot(122)
plt.plot(np.abs(states_euler[:,0]-states_rossler[:,0]))

# %%
for k in range(100):
    if "h" is True:
        pass

# %%
covs_euler = np.load(path+"covs.npy")

# %%
plt.plot(covs_euler[:,0,0])
plt.plot(covs_euler[:,1,0])
plt.plot(covs_euler[:,1,1])
plt.plot(covs_euler[:,0,1])

# %%
covs_euler[-1]
# Out:
# array([[0.72773347, 0.04226151],
#        [0.04226151, 0.72974574]])

# %%
periods = 100
ppp = 100
itraj = 1
method = "euler"
path = get_def_path()
path = path + "{}periods/{}ppp/{}/{}/".format(periods,ppp,method, itraj)
states_euler = np.load(path+"states.npy")
method = "rossler"
path = get_def_path() + "{}periods/{}ppp/{}/{}/".format(periods,ppp,method, itraj)
states_rossler = np.load(path+"states.npy")

# %%
plt.figure(figsize=(30,10))
plt.suptitle("dt = 0.01", size=40)
plt.subplot(121)
plt.plot(states_rossler[:,0])
plt.plot(states_euler[:,0])
plt.subplot(122)
plt.plot(np.abs(states_euler[:,0]-states_rossler[:,0]))

# %%
periods = 100
ppp = 1000
itraj = 1
method = "euler"
path = get_def_path()
path = path + "{}periods/{}ppp/{}/{}/".format(periods,ppp,method, itraj)
states_euler = np.load(path+"states.npy")
method = "rossler"
path = get_def_path() + "{}periods/{}ppp/{}/{}/".format(periods,ppp,method, itraj)
states_rossler = np.load(path+"states.npy")

plt.figure(figsize=(20,10))
plt.suptitle("dt = 0.001", size=40)
plt.subplot(121)
plt.plot(states_rossler[:,0])
plt.plot(states_euler[:,0])
plt.subplot(122)
plt.plot(np.abs(states_euler[:,0]-states_rossler[:,0]))

# %%
periods = 100
ppp = 10000
itraj = 1
method = "euler"
path = get_def_path()
path = path + "{}periods/{}ppp/{}/{}/".format(periods,ppp,method, itraj)
states_euler = np.load(path+"states.npy")
method = "rossler"
path = get_def_path() + "{}periods/{}ppp/{}/{}/".format(periods,ppp,method, itraj)
states_rossler = np.load(path+"states.npy")

plt.figure(figsize=(20,10))
plt.suptitle("dt = 0.001", size=40)
plt.subplot(121)
plt.plot(states_rossler[:,0])
plt.plot(states_euler[:,0])
plt.subplot(122)
plt.plot(np.abs(states_euler[:,0]-states_rossler[:,0]))
